# %%
import numpy as np
import pandas as pd

data = pd.read_csv('dataset.csv')

print(data.head())



# Read raw data with error tolerance
raw = pd.read_csv('dataset.csv', on_bad_lines='skip', engine='python')

# Standardize formatting
clean = raw.replace({'“': '"', '”': '"', '，': ','}, regex=True)  # Fix quotes
clean = clean.apply(lambda x: x.str.strip(' @') if x.dtype == "object" else x)  # Remove @ symbols

# Save cleaned version
clean.to_csv('cleaned_data.csv', index=False, quoting=1)




def baseline_linear_model(prev_price, occupancy, capacity, alpha=0.5):
    """
    Simple linear model where price increases with occupancy rate

    Args:
        prev_price: Previous time step's price
        occupancy: Current number of parked vehicles
        capacity: Maximum capacity of parking lot
        alpha: Sensitivity parameter (default 0.5)

    Returns:
        Next time step's price
    """
    occupancy_rate = occupancy / capacity
    price_change = alpha * occupancy_rate
    new_price = prev_price + price_change

    # Ensure price stays within reasonable bounds
    new_price = max(10, min(20, new_price))  # Between $10-$20

    return round(new_price, 2)
# Out:
#    ID SystemCodeNumber  Capacity   Latitude  Longitude  Occupancy VehicleType  \
# 0   0      BHMBCCMKT01       577  26.144536  91.736172         61         car
# 1   1      BHMBCCMKT01       577  26.144536  91.736172         64         car
# 2   2      BHMBCCMKT01       577  26.144536  91.736172         80         car
# 3   3      BHMBCCMKT01       577  26.144536  91.736172        107         car
# 4   4      BHMBCCMKT01       577  26.144536  91.736172        150        bike
#
#   TrafficConditionNearby  QueueLength  IsSpecialDay LastUpdatedDate  \
# 0                    low            1             0      04-10-2016
# 1                    low            1             0      04-10-2016
# 2                    low            2             0      04-10-2016
# 3                    low            2             0      04-10-2016
# 4                    low            2             0      04-10-2016
#
#   LastUpdatedTime
# 0        07:59:00
# 1        08:25:00
# 2        08:59:00
# 3        09:32:00
# 4        09:59:00

# %%
def demand_based_model(base_price, current_state, params):
    """
    Advanced demand-based pricing model

    Args:
        base_price: $10 base price
        current_state: Dictionary containing:
            - occupancy
            - capacity
            - queue_length
            - traffic_level (0-1 normalized)
            - is_special_day (boolean)
            - vehicle_type (weights: car=1, bike=0.7, truck=1.3)
        params: Dictionary of model parameters (alpha, beta, gamma, delta, epsilon, lambda)

    Returns:
        Adjusted price based on demand factors
    """
    # Extract features
    occupancy_rate = current_state['occupancy'] / current_state['capacity']
    queue_length = current_state['queue_length']
    traffic_level = current_state['traffic_level']
    is_special_day = current_state['is_special_day']
    vehicle_type = current_state['vehicle_type']

    # Vehicle type weights
    vehicle_weights = {'car': 1.0, 'bike': 0.7, 'truck': 1.3}
    vehicle_weight = vehicle_weights.get(vehicle_type, 1.0)

    # Calculate demand score
    demand_score = (
        params['alpha'] * occupancy_rate +
        params['beta'] * queue_length -
        params['gamma'] * traffic_level +
        params['delta'] * is_special_day +
        params['epsilon'] * vehicle_weight
    )

    # Normalize demand score to [0, 1] range
    max_demand = (params['alpha'] + params['beta'] + params['delta'] + params['epsilon'] * 1.3)
    normalized_demand = max(0, min(1, demand_score / max_demand))

    # Calculate adjusted price
    adjusted_price = base_price * (1 + params['lambda'] * normalized_demand)

    # Apply bounds (0.5x to 2x base price)
    adjusted_price = max(base_price * 0.5, min(base_price * 2, adjusted_price))

    return round(adjusted_price, 2)

# %%
from geopy.distance import geodesic

def competitive_pricing_model(base_price, current_state, competitor_data, params):
    """
    Competitive pricing model considering nearby parking lots

    Args:
        base_price: $10 base price
        current_state: Dictionary containing all Model 2 features plus:
            - latitude
            - longitude
        competitor_data: List of dictionaries with competitor info:
            - latitude
            - longitude
            - price
            - occupancy
            - capacity
        params: Dictionary of model parameters (includes all Model 2 params plus new ones)

    Returns:
        Adjusted price considering competition
    """
    # First calculate demand-based price
    demand_price = demand_based_model(base_price, current_state, params)

    # Find nearby competitors (within 0.5 km)
    current_location = (current_state['latitude'], current_state['longitude'])
    nearby_competitors = []

    for competitor in competitor_data:
        comp_location = (competitor['latitude'], competitor['longitude'])
        distance = geodesic(current_location, comp_location).km
        if distance <= 0.5:  # 0.5 km radius
            nearby_competitors.append(competitor)

    if not nearby_competitors:
        return demand_price  # No competition nearby

    # Calculate competitive factors
    avg_competitor_price = np.mean([c['price'] for c in nearby_competitors])
    min_competitor_price = min([c['price'] for c in nearby_competitors])
    competitor_occupancy_rates = [c['occupancy']/c['capacity'] for c in nearby_competitors]

    # Adjust price based on competition
    if current_state['occupancy'] / current_state['capacity'] > 0.9:  # Nearly full
        # If we're more expensive than cheapest competitor, match or slightly undercut
        if demand_price > min_competitor_price:
            adjusted_price = min_competitor_price * 0.98  # 2% discount
        else:
            adjusted_price = demand_price
    else:
        # Price based on our demand but relative to market average
        market_position = params.get('market_position', 1.0)  # 1.0 = average
        adjusted_price = demand_price * (avg_competitor_price / base_price) * market_position

    # Final bounds check
    adjusted_price = max(base_price * 0.5, min(base_price * 2, adjusted_price))

    return round(adjusted_price, 2)

# %%
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.layouts import gridplot
from bokeh.io import output_notebook
output_notebook()

def plot_real_time_pricing(pricing_data):
    """Create real-time pricing visualization"""

    # Prepare data source
    source = ColumnDataSource(pricing_data)

    # Create main price plot
    price_plot = figure(
        title="Real-Time Parking Prices",
        x_axis_label="Time",
        y_axis_label="Price ($)",
        width=800,
        height=400,
        x_axis_type="datetime"
    )

    price_plot.line(
        x='timestamp',
        y='price',
        source=source,
        line_width=2,
        legend_label="Price",
        color="blue"
    )

    # Add hover tool
    hover = HoverTool(tooltips=[
        ("Time", "@timestamp{%F %T}"),
        ("Price", "$@price{0.2f}"),
        ("Occupancy", "@occupancy_rate{0.0%}"),
    ], formatters={'@timestamp': 'datetime'})

    price_plot.add_tools(hover)

    # Create demand factors plot
    factors_plot = figure(
        title="Demand Factors",
        x_axis_label="Time",
        y_axis_label="Impact",
        width=800,
        height=300,
        x_axis_type="datetime",
        x_range=price_plot.x_range
    )

    colors = ["red", "green", "blue", "orange"]
    factors = ['queue_impact', 'traffic_impact', 'special_day_impact', 'vehicle_type_impact']
    labels = ['Queue', 'Traffic', 'Special Day', 'Vehicle Type']

    for factor, color, label in zip(factors, colors, labels):
        factors_plot.line(
            x='timestamp',
            y=factor,
            source=source,
            line_width=1.5,
            legend_label=label,
            color=color
        )

    factors_plot.legend.location = "top_left"

    # Combine plots
    grid = gridplot([[price_plot], [factors_plot]])
    show(grid)

# %%
import pathway as pw

# ───────────────────────────────────────────────────────────
# 1. Raw schema that matches the CSV header row 1‑for‑1
# ───────────────────────────────────────────────────────────
class RawParkingSchema(pw.Schema):
    ID: int
    SystemCodeNumber: str
    Capacity: int
    Latitude: float
    Longitude: float
    Occupancy: int
    VehicleType: str
    TrafficConditionNearby: str
    QueueLength: int
    IsSpecialDay: bool
    LastUpdatedDate: str
    LastUpdatedTime: str


# ───────────────────────────────────────────────────────────
# 2. Read CSV (header already present → no extra settings)
# ───────────────────────────────────────────────────────────
raw_table = pw.io.csv.read(
    "dataset.csv",
    schema=RawParkingSchema
)

# ───────────────────────────────────────────────────────────
# 3. Rename/clean the columns so we avoid the reserved “id”
# ───────────────────────────────────────────────────────────
input_table = raw_table.select(
    row_id           = pw.this.ID,                      # rename!
    parking_id       = pw.this.SystemCodeNumber,
    capacity         = pw.this.Capacity,
    latitude         = pw.this.Latitude,
    longitude        = pw.this.Longitude,
    occupancy        = pw.this.Occupancy,
    vehicle_type     = pw.this.VehicleType,
    traffic_level    = pw.this.TrafficConditionNearby,
    queue_length     = pw.this.QueueLength,
    is_special_day   = pw.this.IsSpecialDay,
    last_updated_date= pw.this.LastUpdatedDate,
    last_updated_time= pw.this.LastUpdatedTime
)


# ───────────────────────────────────────────────────────────
# 4. Pricing logic
# ───────────────────────────────────────────────────────────
def demand_based_model(base_price: float, state: dict, params: dict) -> float:
    traffic_factor = {"low": 0.9, "average": 1.0, "high": 1.2}.get(
        state["traffic_level"].lower(), 1.0
    )
    occupancy_ratio   = state["occupancy"] / max(state["capacity"], 1)
    queue_factor      = 1 + 0.05 * state["queue_length"]
    special_day_mult  = 1.25 if state["is_special_day"] else 1.0
    vehicle_mult      = {
        "car": 1.0, "bike": 0.6, "truck": 1.5, "cycle": 0.4
    }.get(state["vehicle_type"].lower(), 1.0)

    price = (base_price *
             (1 + params["alpha"] * occupancy_ratio) *
             traffic_factor *
             queue_factor *
             special_day_mult *
             vehicle_mult)
    return round(price, 2)


def process_row(**row):
    base_price = 10.0
    params = {
        "alpha": 0.8, "beta": 0.3, "gamma": 0.2,
        "delta": 0.5, "epsilon": 0.4, "lambda": 0.7
    }
    return demand_based_model(base_price, row, params)


# ───────────────────────────────────────────────────────────
# 5. Enrich with price & occupancy_rate
# ───────────────────────────────────────────────────────────
output_table = input_table.select(
    **input_table,                                        # keep cleaned cols
    price          = pw.apply(process_row, **input_table),
    occupancy_rate = pw.this.occupancy / pw.this.capacity
)

# ───────────────────────────────────────────────────────────
# 6. Persist results
# ───────────────────────────────────────────────────────────
pw.io.csv.write(output_table, "output_prices.csv")

# ───────────────────────────────────────────────────────────
# 7. Run the pipeline
# ───────────────────────────────────────────────────────────
pw.run()
# Out:
# /tmp/ipython-input-67-2272277012.py:85: DeprecationWarning: Passing keyword arguments to the function in pw.apply is deprecated. Use positional arguments instead.
#   price          = pw.apply(process_row, **input_table),
# Output()
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["ID", "SystemCodeNumber", "Capacity", "Latitude", "Longitude", "Occupancy", "VehicleType", "TrafficConditionNearby", "QueueLength", "IsSpecialDay", "LastUpdatedDate", "LastUpdatedTime"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["0", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "61", "car", "low", "1", "0", "04-10-2016", "07:59:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["1", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "64", "car", "low", "1", "0", "04-10-2016", "08:25:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["2", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "80", "car", "low", "2", "0", "04-10-2016", "08:59:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["3", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "107", "car", "low", "2", "0", "04-10-2016", "09:32:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["7", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "247", "car", "average", "5", "0", "04-10-2016", "11:25:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["8", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "259", "cycle", "average", "5", "0", "04-10-2016", "11:59:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["9", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "266", "bike", "high", "8", "0", "04-10-2016", "12:29:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["10", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "269", "car", "high", "7", "0", "04-10-2016", "13:02:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["11", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "263", "car", "high", "7", "0", "04-10-2016", "13:29:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["12", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "238", "car", "high", "5", "0", "04-10-2016", "14:02:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["13", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "215", "truck", "average", "3", "0", "04-10-2016", "14:29:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["31", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "158", "car", "high", "5", "0", "05-10-2016", "14:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["32", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "145", "car", "average", "3", "0", "05-10-2016", "14:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["33", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "129", "car", "low", "2", "0", "05-10-2016", "15:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["34", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "121", "car", "low", "2", "0", "05-10-2016", "16:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["35", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "114", "bike", "low", "1", "0", "05-10-2016", "16:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["36", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "58", "car", "low", "1", "0", "06-10-2016", "07:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["37", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "63", "car", "low", "1", "0", "06-10-2016", "08:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["38", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "70", "car", "low", "1", "0", "06-10-2016", "08:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["39", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "95", "car", "low", "2", "0", "06-10-2016", "09:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["40", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "135", "car", "low", "3", "0", "06-10-2016", "10:03:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["41", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "160", "car", "average", "3", "0", "06-10-2016", "10:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["42", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "177", "car", "average", "3", "0", "06-10-2016", "10:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["43", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "191", "cycle", "average", "4", "0", "06-10-2016", "11:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["44", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "199", "car", "high", "7", "0", "06-10-2016", "12:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["45", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "206", "car", "high", "7", "0", "06-10-2016", "12:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["46", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "198", "car", "average", "5", "0", "06-10-2016", "12:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["47", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "208", "bike", "high", "7", "0", "06-10-2016", "13:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["48", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "200", "car", "average", "5", "0", "06-10-2016", "13:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["49", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "175", "cycle", "average", "3", "0", "06-10-2016", "14:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["50", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "158", "car", "low", "2", "0", "06-10-2016", "15:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["51", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "153", "bike", "low", "2", "0", "06-10-2016", "15:31:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["52", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "135", "bike", "low", "1", "0", "06-10-2016", "16:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["53", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "129", "car", "low", "2", "0", "06-10-2016", "16:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["58", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "128", "bike", "low", "2", "0", "07-10-2016", "09:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["59", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "172", "truck", "high", "5", "0", "07-10-2016", "10:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["60", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "188", "car", "average", "3", "0", "07-10-2016", "10:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["61", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "199", "bike", "average", "4", "0", "07-10-2016", "11:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["62", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "210", "car", "high", "7", "0", "07-10-2016", "12:03:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["63", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "206", "bike", "high", "7", "0", "07-10-2016", "12:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["64", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "200", "car", "high", "7", "0", "07-10-2016", "13:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["65", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "201", "car", "high", "7", "0", "07-10-2016", "13:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["66", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "193", "bike", "average", "3", "0", "07-10-2016", "14:03:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["67", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "181", "car", "average", "4", "0", "07-10-2016", "14:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["68", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "172", "truck", "low", "2", "0", "07-10-2016", "15:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["69", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "159", "cycle", "low", "2", "0", "07-10-2016", "15:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["70", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "158", "cycle", "low", "2", "0", "07-10-2016", "15:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["71", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "132", "car", "low", "2", "0", "07-10-2016", "16:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["72", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "58", "car", "low", "1", "0", "08-10-2016", "07:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["73", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "61", "car", "average", "2", "0", "08-10-2016", "08:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["74", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "75", "truck", "low", "1", "0", "08-10-2016", "08:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["75", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "104", "car", "low", "2", "0", "08-10-2016", "09:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["76", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "158", "car", "low", "3", "0", "08-10-2016", "10:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["77", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "191", "truck", "average", "3", "0", "08-10-2016", "10:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["78", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "223", "truck", "average", "4", "0", "08-10-2016", "10:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["79", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "254", "car", "average", "4", "0", "08-10-2016", "11:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["80", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "306", "car", "high", "7", "0", "08-10-2016", "12:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["81", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "320", "car", "high", "8", "0", "08-10-2016", "12:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["82", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "348", "car", "high", "7", "0", "08-10-2016", "13:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["99", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "170", "truck", "high", "9", "1", "09-10-2016", "12:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["100", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "189", "car", "high", "8", "1", "09-10-2016", "13:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["101", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "205", "bike", "high", "9", "1", "09-10-2016", "13:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["102", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "208", "cycle", "high", "7", "1", "09-10-2016", "14:03:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["103", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "209", "car", "average", "5", "1", "09-10-2016", "14:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["104", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "191", "car", "low", "3", "1", "09-10-2016", "15:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["105", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "180", "car", "low", "3", "1", "09-10-2016", "15:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["106", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "155", "truck", "low", "3", "1", "09-10-2016", "16:03:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["107", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "133", "car", "low", "2", "1", "09-10-2016", "16:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["108", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "54", "bike", "low", "1", "0", "10-10-2016", "08:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["109", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "56", "truck", "low", "1", "0", "10-10-2016", "08:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["110", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "65", "car", "low", "1", "0", "10-10-2016", "09:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["111", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "73", "bike", "low", "2", "0", "10-10-2016", "09:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["112", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "92", "cycle", "low", "2", "0", "10-10-2016", "10:03:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["113", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "113", "cycle", "average", "4", "0", "10-10-2016", "10:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["114", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "144", "car", "average", "3", "0", "10-10-2016", "10:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["115", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "149", "car", "average", "4", "0", "10-10-2016", "11:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["116", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "159", "car", "average", "4", "0", "10-10-2016", "11:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["117", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "171", "car", "high", "6", "0", "10-10-2016", "12:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["118", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "176", "truck", "average", "5", "0", "10-10-2016", "13:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["119", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "172", "car", "high", "6", "0", "10-10-2016", "13:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["120", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "161", "car", "high", "5", "0", "10-10-2016", "14:03:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["121", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "154", "car", "average", "3", "0", "10-10-2016", "14:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["122", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "137", "car", "average", "4", "0", "10-10-2016", "14:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["123", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "129", "bike", "low", "1", "0", "10-10-2016", "15:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["124", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "130", "car", "average", "3", "0", "10-10-2016", "15:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["125", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "114", "truck", "low", "2", "0", "10-10-2016", "16:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["126", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "56", "bike", "average", "1", "0", "11-10-2016", "08:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Too many parse errors, some of them will be omitted...
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["ID", "SystemCodeNumber", "Capacity", "Latitude", "Longitude", "Occupancy", "VehicleType", "TrafficConditionNearby", "QueueLength", "IsSpecialDay", "LastUpdatedDate", "LastUpdatedTime"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["0", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "61", "car", "low", "1", "0", "04-10-2016", "07:59:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["1", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "64", "car", "low", "1", "0", "04-10-2016", "08:25:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["2", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "80", "car", "low", "2", "0", "04-10-2016", "08:59:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["3", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "107", "car", "low", "2", "0", "04-10-2016", "09:32:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["4", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "150", "bike", "low", "2", "0", "04-10-2016", "09:59:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["5", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "177", "car", "low", "3", "0", "04-10-2016", "10:26:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["6", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "219", "truck", "high", "6", "0", "04-10-2016", "10:59:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["7", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "247", "car", "average", "5", "0", "04-10-2016", "11:25:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["8", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "259", "cycle", "average", "5", "0", "04-10-2016", "11:59:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["9", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "266", "bike", "high", "8", "0", "04-10-2016", "12:29:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["10", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "269", "car", "high", "7", "0", "04-10-2016", "13:02:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["11", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "263", "car", "high", "7", "0", "04-10-2016", "13:29:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["12", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "238", "car", "high", "5", "0", "04-10-2016", "14:02:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["13", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "215", "truck", "average", "3", "0", "04-10-2016", "14:29:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["14", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "192", "bike", "average", "3", "0", "04-10-2016", "14:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["15", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "165", "car", "low", "2", "0", "04-10-2016", "15:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["16", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "162", "bike", "low", "1", "0", "04-10-2016", "16:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["17", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "143", "car", "average", "2", "0", "04-10-2016", "16:31:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["18", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "54", "car", "low", "1", "0", "05-10-2016", "07:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["19", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "59", "car", "average", "1", "0", "05-10-2016", "08:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["20", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "71", "car", "low", "2", "0", "05-10-2016", "09:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["21", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "83", "car", "average", "2", "0", "05-10-2016", "09:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["40", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "135", "car", "low", "3", "0", "06-10-2016", "10:03:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["41", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "160", "car", "average", "3", "0", "06-10-2016", "10:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["42", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "177", "car", "average", "3", "0", "06-10-2016", "10:57:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["43", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "191", "cycle", "average", "4", "0", "06-10-2016", "11:30:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["44", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "199", "car", "high", "7", "0", "06-10-2016", "12:04:00"], fields specified in connector: ["timestamp", "parking_id", "latitude", "longitude", "capacity", "occupancy", "queue_length", "vehicle_type", "traffic_level", "is_special_day"])
# ...
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["91", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "42", "bike", "low", "2", "1", "09-10-2016", "08:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["92", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "43", "car", "low", "2", "1", "09-10-2016", "09:04:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["93", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "43", "cycle", "low", "2", "1", "09-10-2016", "09:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["94", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "50", "car", "average", "3", "1", "09-10-2016", "09:57:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["95", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "64", "cycle", "high", "5", "1", "09-10-2016", "10:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["96", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "100", "truck", "average", "6", "1", "09-10-2016", "11:04:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["97", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "126", "car", "average", "6", "1", "09-10-2016", "11:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["98", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "148", "car", "average", "6", "1", "09-10-2016", "11:57:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["99", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "170", "truck", "high", "9", "1", "09-10-2016", "12:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["100", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "189", "car", "high", "8", "1", "09-10-2016", "13:04:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["101", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "205", "bike", "high", "9", "1", "09-10-2016", "13:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["102", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "208", "cycle", "high", "7", "1", "09-10-2016", "14:03:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["103", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "209", "car", "average", "5", "1", "09-10-2016", "14:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["104", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "191", "car", "low", "3", "1", "09-10-2016", "15:04:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["105", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "180", "car", "low", "3", "1", "09-10-2016", "15:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["106", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "155", "truck", "low", "3", "1", "09-10-2016", "16:03:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["107", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "133", "car", "low", "2", "1", "09-10-2016", "16:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["108", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "54", "bike", "low", "1", "0", "10-10-2016", "08:04:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["109", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "56", "truck", "low", "1", "0", "10-10-2016", "08:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["110", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "65", "car", "low", "1", "0", "10-10-2016", "09:04:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["111", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "73", "bike", "low", "2", "0", "10-10-2016", "09:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["112", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "92", "cycle", "low", "2", "0", "10-10-2016", "10:03:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["113", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "113", "cycle", "average", "4", "0", "10-10-2016", "10:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["114", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "144", "car", "average", "3", "0", "10-10-2016", "10:57:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["115", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "149", "car", "average", "4", "0", "10-10-2016", "11:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["116", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "159", "car", "average", "4", "0", "10-10-2016", "11:57:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["117", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "171", "car", "high", "6", "0", "10-10-2016", "12:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["118", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "176", "truck", "average", "5", "0", "10-10-2016", "13:04:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["119", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "172", "car", "high", "6", "0", "10-10-2016", "13:30:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# ERROR:pathway_engine.connectors:Parse error: some fields weren't found in the header (fields present in table: ["120", "BHMBCCMKT01", "577", "26.14453614", "91.73617216", "161", "car", "high", "5", "0", "10-10-2016", "14:03:00"], fields specified in connector: ["ud", "parking_id", "capacity", "latitude", "longitude", "occupancy", "vehicle_type", "traffic_level", "queue_length", "is_special_day", "last_updated_date", "last_updated_time"])
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-67-2272277012.py in <cell line: 0>()
#      95 # 7. Run the pipeline
#      96 # ───────────────────────────────────────────────────────────
# ---> 97 pw.run()
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/runtime_type_check.py in with_type_validation(*args, **kwargs)
#      17         """
#      18         try:
# ---> 19             return beartype.beartype(f)(*args, **kwargs)
#      20         except beartype.roar.BeartypeCallHintParamViolation as e:
#      21             raise TypeError(e) from None
#
# <@beartype(pathway.internals.run.run) at 0x7db169b982c0> in run(__beartype_func, __beartype_conf, __beartype_get_violation, __beartype_object_415433696, __beartype_object_138199197328832, __beartype_object_138199196086464, __beartype_object_9637792, *args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/run.py in run(debug, monitoring_level, with_http_server, default_logging, persistence_config, runtime_typechecking, terminate_on_error, max_expression_batch_size)
#      53         max_expression_batch_size=max_expression_batch_size,
#      54         _stacklevel=4,
# ---> 55     ).run_outputs()
#      56
#      57
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/graph_runner/__init__.py in run_outputs(self, after_build)
#     117         after_build: Callable[[ScopeState, OperatorStorageGraph], None] | None = None,
#     118     ) -> None:
# --> 119         self.run_nodes(self._graph.global_scope.output_nodes, after_build=after_build)
#     120
#     121     def has_bounded_input(self, table: table.Table) -> bool:
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/graph_runner/__init__.py in run_nodes(self, nodes, after_build)
#      93     ):
#      94         all_nodes = self._tree_shake(self._graph.global_scope, nodes)
# ---> 95         self._run(all_nodes, after_build=after_build)
#      96
#      97     def run_tables(
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/graph_runner/__init__.py in _run(self, nodes, output_tables, after_build, run_all)
#     202             ):
#     203                 try:
# --> 204                     return api.run_with_new_graph(
#     205                         logic,
#     206                         event_loop=event_loop,
#
# KeyboardInterrupt:
